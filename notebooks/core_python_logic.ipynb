# %%
x= 10
y= 5
z=7

x*y*z
# Out:
# 350

# %% [markdown]
# i set up three variables, x,y,and z and multiplied them together

# %%
total = x*y*z

# %%
if total >=400:
    print("you are the winner!")
else:
    print("your score is too small, you lose")
# Out:
# your score is too small, you lose

# %% [markdown]
# i created a conditional statement for if the result of the multiplication is above 400, you get a winning score and if not you lose the game

# %%
sum = 1
for i in range (10):
    print(i)
    sum = sum + i
    print ("final sum",sum)
# Out:
# 0
# final sum 1
# 1
# final sum 2
# 2
# final sum 4
# 3
# final sum 7
# 4
# final sum 11
# 5
# final sum 16
# 6
# final sum 22
# 7
# final sum 29
# 8
# final sum 37
# 9
# final sum 46

# %% [markdown]
# i created a loop so the range of numbers from 0 to 10 runs, and then within the loop each time it runs through the loop it adds 1 + the sum of the number in the loops before in a cumulative addition, which is why it grows so much each time
