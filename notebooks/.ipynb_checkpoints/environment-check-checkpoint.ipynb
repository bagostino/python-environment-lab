# %%
print("Python environment successfully configured!")
# Out:
# Python environment successfully configured!

# %% [markdown]
# ## Tile of notebook is environment check and the notebook is meant to test out that i am setting up py files and folder structures properly in Jupyter

# %%
x = 10
y = 4

x-y
# Out:
# 6
